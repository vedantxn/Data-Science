# %%
import numpy as np

# %%
a = np.array([0, 1, 2])
b = np.array([5, 5, 5])
a + b
# Out:
# array([5, 6, 7])

# %%
a + 5
# Out:
# array([5, 6, 7])

# %%
M = np.ones((3, 3))
M

# %%
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])

# %%
a = np.arange(3)
b = np.arange(3)[:, np.newaxis]

print(a)
print(b)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
M = np.ones((2, 3))
a = np.arange(3)
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.]])

# %%
a = np.arange(3).reshape((3, 1))
b = np.arange(3)
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
M = np.ones((3, 2))
a = np.arange(3)
M + a
#an error is raised because the shapes of the arrays are not compatible for broadcasting
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 M = np.ones((3, 2))
#       2 a = np.arange(3)
# ----> 3 M + a
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %%
a[:, np.newaxis].shape
M + a[:, np.newaxis]

np.logaddexp(M, a[:, np.newaxis])
# Out:
# array([[1.31326169, 1.31326169],
#        [1.69314718, 1.69314718],
#        [2.31326169, 2.31326169]])

# %%
X = np.random.random((10, 3))
Xmean = X.mean(0)
Xmean
# Out:
# array([0.53043957, 0.39280785, 0.47704238])

# %%
X_centered = X - Xmean
X_centered.mean(0)
# Out:
# array([-3.33066907e-17,  0.00000000e+00, -3.88578059e-17])

# %%
A = np.random.randint(1, 10, (5, 3))
print("original array:\n", A)

column_means = A.mean(0)

A_centered = A - column_means
A_centered
# Out:
# original array:
#  [[6 1 6]
#  [6 6 7]
#  [2 3 7]
#  [8 4 4]
#  [6 9 5]]
# array([[ 0.4, -3.6,  0.2],
#        [ 0.4,  1.4,  1.2],
#        [-3.6, -1.6,  1.2],
#        [ 2.4, -0.6, -1.8],
#        [ 0.4,  4.4, -0.8]])

# %%
import matplotlib.pyplot as plt

# Define x and y ranges
x = np.linspace(-2, 2, 100)  # 100 points from -2 to 2
y = np.linspace(-2, 2, 100)  # 100 points from -2 to 2

# Create a 2D grid using broadcasting
X, Y = np.meshgrid(x, y)

# Compute function values
Z = np.sin(X**2 + Y**2)  # Broadcasting applies automatically

# Plot the function
plt.figure(figsize=(8,6))
plt.contourf(X, Y, Z, cmap='viridis')  # Filled contour plot
plt.colorbar(label="Function Value")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Contour Plot of f(x, y) = sin(x² + y²)")
plt.show()

# %%
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)

X, Y = np.meshgrid(x, y)
Z = np.exp(-(X**2 + Y**2))  # Gaussian function

plt.figure(figsize=(8,6))
plt.contourf(X, Y, Z, cmap='inferno')
plt.colorbar(label="Function Value")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Gaussian Function: $e^{-(x^2 + y^2)}$")
plt.show()

# %%
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

X, Y = np.meshgrid(x, y)
Z = np.sin(5 * X) * np.cos(5 * Y)

plt.figure(figsize=(8,6))
plt.contourf(X, Y, Z, cmap='coolwarm')
plt.colorbar(label="Function Value")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sinusoidal Function: $sin(5x) \\cdot cos(5y)$")
plt.show()

# %%
x = np.linspace(-2, 2, 200)
y = np.linspace(-2, 2, 200)

X, Y = np.meshgrid(x, y)
Z = np.sin(10 * np.sqrt(X**2 + Y**2))

plt.figure(figsize=(8,6))
plt.contourf(X, Y, Z, cmap='plasma')
plt.colorbar(label="Function Value")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Radial Sine Function: $sin(10 \\sqrt{x^2 + y^2})$")
plt.show()
